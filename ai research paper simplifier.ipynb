# %%
import numpy as np
import pandas as pd
import streamlit as st

# %%
st.title("🚀 AI Paper Simplifier")
# Out:
# 2026-04-11 11:29:30.250 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-11 11:29:31.936
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\varin\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-04-11 11:29:31.941 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-11 11:29:31.941 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
import sys
sys.path.append(".")
from services.pdf_extractor import extract_text
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 3
#       1 import sys
#       2 sys.path.append(".")
# ----> 3 from services.pdf_extractor import extract_text
#
# ModuleNotFoundError: No module named 'services'

# %%
import streamlit as st
import numpy as np
import pandas as pd
st.title("AI Research Dashboard")
import pdfplumber
from services.pdf_extractor import extract_text
def extract_text(file):
    text = ""
    with pdfplumber.open(file) as pdf:
        for page in pdf.pages:
            text += page.extract_text() or ""
    return text
    
from services.pdf_extractor import extract_text

st.title("📄 AI Research Paper Simplifier")

uploaded_file = st.file_uploader("Upload a Research Paper (PDF)", type=["pdf"])

if uploaded_file is not None:
    st.write("📥 File uploaded successfully!")

    text = extract_text(uploaded_file)
# Out:
# 2026-04-11 11:55:00.110 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-11 11:55:00.126 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-11 11:55:00.126 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 6
#       4 st.title("AI Research Dashboard")
#       5 import pdfplumber
# ----> 6 from services.pdf_extractor import extract_text
#       7 def extract_text(file):
#       8     text = ""
#
# ModuleNotFoundError: No module named 'services'
